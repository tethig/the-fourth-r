# %% [markdown]
# # Preparing a Plot from Time Series Data

# %% [markdown]
# The data here is one week's worth of my heart rate data in 10s intervals.

# %% [markdown]
# ## Requirements

# %%
library(jsonlite)
library(tidyverse)
library(lubridate)

# %%
jsonData <- readLines("heartdata.json", skipNul = TRUE)

# %%
jsonData <- gsub('\'', '\"', jsonData)

# %%
heartdata <- data.frame()
for (entry in jsonData) {
    #cleaned <- gsub("\n", "", entry)
    converted <- fromJSON(entry)
    heartentry <- converted$`activities-heart-intraday`$dataset
    heartentry$date <- converted$`activities-heart`$dateTime
    heartdata <- rbind(heartdata, heartentry)
    }

# %%
(heartdata <- as_tibble(heartdata))
# Out:
#       time     value date
# 1     00:00:04 75    2017-05-01
# 2     00:00:09 77    2017-05-01
# 3     00:00:19 77    2017-05-01
# 4     00:00:29 79    2017-05-01
# 5     00:00:44 79    2017-05-01
# 6     00:00:49 80    2017-05-01
# 7     00:00:54 80    2017-05-01
# 8     00:00:59 81    2017-05-01
# 9     00:01:04 82    2017-05-01
# 10    00:01:14 83    2017-05-01
# 11    00:01:29 83    2017-05-01
# 12    00:01:34 84    2017-05-01
# 13    00:01:49 84    2017-05-01
# 14    00:01:59 82    2017-05-01
# 15    00:02:04 81    2017-05-01
# 16    00:02:19 81    2017-05-01
# 17    00:02:34 81    2017-05-01
# 18    00:02:36 81    2017-05-01
# 19    00:02:51 81    2017-05-01
# 20    00:02:56 81    2017-05-01
# 21    00:03:06 81    2017-05-01
# 22    00:03:21 80    2017-05-01
# 23    00:03:26 79    2017-05-01
# 24    00:03:31 79    2017-05-01
# 25    00:03:41 77    2017-05-01
# 26    00:03:46 76    2017-05-01
# 27    00:04:01 76    2017-05-01
# 28    00:04:16 76    2017-05-01
# 29    00:04:31 76    2017-05-01
# 30    00:04:46 76    2017-05-01
# ⋮     ⋮        ⋮     ⋮
# 64705 23:55:11 62    2017-05-07
# 64706 23:55:26 62    2017-05-07
# 64707 23:55:36 63    2017-05-07
# 64708 23:55:41 62    2017-05-07
# 64709 23:55:46 63    2017-05-07
# 64710 23:55:51 63    2017-05-07
# 64711 23:56:06 63    2017-05-07
# 64712 23:56:21 63    2017-05-07
# 64713 23:56:31 61    2017-05-07
# 64714 23:56:36 59    2017-05-07
# 64715 23:56:41 59    2017-05-07
# 64716 23:56:48 59    2017-05-07
# 64717 23:56:53 58    2017-05-07
# 64718 23:57:08 58    2017-05-07
# 64719 23:57:18 57    2017-05-07
# 64720 23:57:23 56    2017-05-07
# 64721 23:57:33 59    2017-05-07
# 64722 23:57:38 62    2017-05-07
# 64723 23:57:43 63    2017-05-07
# 64724 23:57:48 62    2017-05-07
# 64725 23:57:53 61    2017-05-07
# 64726 23:57:58 60    2017-05-07
# 64727 23:58:03 62    2017-05-07
# 64728 23:58:08 62    2017-05-07
# 64729 23:58:23 62    2017-05-07
# 64730 23:58:38 61    2017-05-07
# 64731 23:58:43 60    2017-05-07
# 64732 23:58:48 63    2017-05-07
# 64733 23:58:53 62    2017-05-07
# 64734 23:58:58 65    2017-05-07

# %% [markdown]
# The time format (%H:%M:%S) and date format (%Y-%m-%d) are excellent and are already the defaults for the relevant parse_* functions.

# %%
heartdata$date <- parse_date(heartdata$date)
heartdata$time <- parse_time(heartdata$time)

# %%
hearttheme <- theme_bw() +
theme(
    axis.text = element_text(size=6),
    axis.text.x = element_text(angle=30, hjust=1),
    #panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
)
theme_set(hearttheme)

# %%
breaks <- paste(0:24,":00",sep="")

# %%
ggplot(heartdata, aes(x=time, y=value)) +
geom_point(alpha=0.3, shape=20, size=0.8) +
scale_x_time(breaks=hm(breaks), labels=breaks) +
facet_grid(date~.) +
xlab("Time of Day") +
ylab("Beats per Minute")
#scale_y_continuous(breaks=beatrange, name="Heart Rate (bpm)")
# Out:
# plot without title

# %%
ggsave("heartdata_week.pdf", width=8, height=14, units="in")

# %%
#minbeat = floor(min(heartdata$value/10))*10
#maxbeat = ceiling(max(heartdata$value/10))*10
#beatrange = seq(minbeat,maxbeat,by=10)
